# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd

# %% [markdown]
# **Dataset Collection and Extraction**

# %%
data_train = np.load('C:/Users/PALLAVI/Downloads/Parkinson_disease_detection/train_set.npz', allow_pickle=True)
print(data_train.files)
x_train = data_train['arr_0']
y_train = data_train['arr_1']
print(x_train.shape)
print(y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (72, 256, 256, 3)
# (72,)

# %% [markdown]
# Loading **Dataset**

# %%
data_test = np.load('C:/Users/PALLAVI/Downloads/Parkinson_disease_detection/test_set.npz', allow_pickle=True)
x_test = data_test['arr_0']
y_test = data_test['arr_1']

print(x_test.shape)
print(y_test.shape)
# Out:
# (30, 256, 256, 3)
# (30,)

# %% [markdown]
# **Data Distribution**

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(10, 5))
# Pass x and y as named arguments
sns.barplot(x=unique_train, y=count).set_title("Number of training images per category:")
plt.show()

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(10,5))
sns.barplot(x=unique_test,y=count_test).set_title("Number of testing images per category:")
plt.show()

# %% [markdown]
# **Data Augmentation**

# %%
train_data_generator = ImageDataGenerator(rotation_range=360,
                                    width_shift_range=0.0,
                                    height_shift_range=0.0,
#                                     brightness_range=[0.5, 1.5],
                                
                                    horizontal_flip=True,
                                    vertical_flip=True)

x = list(x_train)
y = list(y_train)

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)
print(len(x_aug_train))
print(len(y_aug_train))

x_train = x + x_aug_train
y_train = y + y_aug_train
print(len(x_train))
print(len(y_train))

test_data_generator = ImageDataGenerator(rotation_range=360,
                                    width_shift_range=0.0,
                                    height_shift_range=0.0,
                            
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True,
                                    vertical_flip=True)

x = list(x_test)
y = list(y_test)

x_aug_test = []
y_aug_test = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(20):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)
print(len(x_aug_test))
print(len(y_aug_test))

x_test = x + x_aug_test
y_test = y + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 5040
# 5040
# 5112
# 5112
# 600
# 600
# 630
# 630

# %% [markdown]
# **Visualizing the Images in Train and Test Set**
#
# Images in Train Set

# %%
# print(y_test)
figure1 = plt.figure(figsize=(2,2))
idx_healthy = [i for (i, v) in enumerate(y_train) if v=='healthy']
img_healthy = x_train[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(2,2))
idx_parkinson = [i for (i, v) in enumerate(y_train) if v=='parkinson']
img_parkinson = x_train[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %% [markdown]
# Images in Test set

# %%
figure1 = plt.figure(figsize=(2,2))
idx_healthy = [i for (i, v) in enumerate(y_test) if v=='healthy']
img_healthy = x_test[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(2,2))
idx_parkinson = [i for (i, v) in enumerate(y_test) if v=='parkinson']
img_parkinson = x_test[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %% [markdown]
# **Preprocessing the Images in the dataset**

# %%
for i in range(len(x_train)):
    img = x_train[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_train[i] = img

for i in range(len(x_test)):
    img = x_test[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_test[i] = img

x_train = np.array(x_train)
x_test = np.array(x_test)

x_train = x_train/255.0
x_test = x_test/255.0

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
print(y_train.shape)

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
print(y_test.shape)
# Out:
# (5112,)
# (630,)

# %% [markdown]
# **Data Distribution after Augmentation**

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(10, 5))
sns.barplot(x=unique_train, y=count).set_title("Number of training images per category after augmentation:")
plt.show()

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(10, 5))
sns.barplot(x=unique_test, y=count_test).set_title("Number of test set images per category after augmentation:")
plt.show()

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (5112, 128, 128, 1)
# (5112, 2)
# (630, 128, 128, 1)
# (630, 2)

# %%
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))

    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))

    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))

    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                  │ (None, 128, 128, 128)  │         3,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 40, 40, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 40, 40, 64)     │       204,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 12, 12, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4 (Conv2D)                  │ (None, 4, 4, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 1, 1, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc3 (Dense)                     │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 238,146 (930.26 KB)
#  Trainable params: 238,146 (930.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
hist = model.fit(x_train, y_train, batch_size=128, epochs=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 215s 5s/step - accuracy: 0.5071 - loss: 0.8544 - val_accuracy: 0.5635 - val_loss: 0.8482
# Epoch 2/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 194s 5s/step - accuracy: 0.5128 - loss: 0.8463 - val_accuracy: 0.5000 - val_loss: 0.8414
# Epoch 3/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 189s 5s/step - accuracy: 0.5019 - loss: 0.8404 - val_accuracy: 0.5000 - val_loss: 0.8347
# Epoch 4/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 187s 5s/step - accuracy: 0.4905 - loss: 0.8339 - val_accuracy: 0.5841 - val_loss: 0.8286
# Epoch 5/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 210s 5s/step - accuracy: 0.4967 - loss: 0.8274 - val_accuracy: 0.5635 - val_loss: 0.8229
# Epoch 6/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 242s 6s/step - accuracy: 0.5113 - loss: 0.8213 - val_accuracy: 0.5603 - val_loss: 0.8175
# Epoch 7/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 204s 5s/step - accuracy: 0.5264 - loss: 0.8156 - val_accuracy: 0.5000 - val_loss: 0.8119
# Epoch 8/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 240s 5s/step - accuracy: 0.5087 - loss: 0.8114 - val_accuracy: 0.5000 - val_loss: 0.8071
# Epoch 9/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 194s 5s/step - accuracy: 0.5196 - loss: 0.8057 - val_accuracy: 0.5032 - val_loss: 0.8023
# Epoch 10/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.5147 - loss: 0.8014 - val_accuracy: 0.5000 - val_loss: 0.7973
# Epoch 11/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.5330 - loss: 0.7963 - val_accuracy: 0.7968 - val_loss: 0.7931
# Epoch 12/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.5535 - loss: 0.7920 - val_accuracy: 0.6175 - val_loss: 0.7895
# Epoch 13/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.5523 - loss: 0.7872 - val_accuracy: 0.5000 - val_loss: 0.7846
# Epoch 14/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.5383 - loss: 0.7840 - val_accuracy: 0.6190 - val_loss: 0.7802
# Epoch 15/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.5529 - loss: 0.7804 - val_accuracy: 0.6619 - val_loss: 0.7752
# Epoch 16/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 200s 5s/step - accuracy: 0.5641 - loss: 0.7774 - val_accuracy: 0.7603 - val_loss: 0.7688
# Epoch 17/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.5939 - loss: 0.7706 - val_accuracy: 0.5524 - val_loss: 0.7646
# Epoch 18/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.5895 - loss: 0.7662 - val_accuracy: 0.5540 - val_loss: 0.7687
# Epoch 19/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.5650 - loss: 0.7641 - val_accuracy: 0.5841 - val_loss: 0.7630
# Epoch 20/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.5895 - loss: 0.7592 - val_accuracy: 0.7825 - val_loss: 0.7490
# Epoch 21/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.6324 - loss: 0.7499 - val_accuracy: 0.7429 - val_loss: 0.7434
# Epoch 22/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.6327 - loss: 0.7441 - val_accuracy: 0.6651 - val_loss: 0.7400
# Epoch 23/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.6485 - loss: 0.7362 - val_accuracy: 0.7016 - val_loss: 0.7286
# Epoch 24/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 191s 5s/step - accuracy: 0.6473 - loss: 0.7299 - val_accuracy: 0.7032 - val_loss: 0.7226
# Epoch 25/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.6773 - loss: 0.7172 - val_accuracy: 0.7778 - val_loss: 0.7092
# Epoch 26/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.6901 - loss: 0.7034 - val_accuracy: 0.6413 - val_loss: 0.7210
# Epoch 27/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.7117 - loss: 0.6948 - val_accuracy: 0.6460 - val_loss: 0.7052
# Epoch 28/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.7088 - loss: 0.6842 - val_accuracy: 0.7190 - val_loss: 0.6846
# Epoch 29/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.7099 - loss: 0.6755 - val_accuracy: 0.7381 - val_loss: 0.6756
# Epoch 30/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.7065 - loss: 0.6696 - val_accuracy: 0.7349 - val_loss: 0.6721
# Epoch 31/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.7052 - loss: 0.6624 - val_accuracy: 0.7365 - val_loss: 0.6584
# Epoch 32/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 191s 5s/step - accuracy: 0.7333 - loss: 0.6415 - val_accuracy: 0.6619 - val_loss: 0.6633
# Epoch 33/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 195s 5s/step - accuracy: 0.7453 - loss: 0.6253 - val_accuracy: 0.7016 - val_loss: 0.6483
# Epoch 34/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.7455 - loss: 0.6332 - val_accuracy: 0.7540 - val_loss: 0.6296
# Epoch 35/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.7626 - loss: 0.6090 - val_accuracy: 0.7063 - val_loss: 0.6331
# Epoch 36/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.7648 - loss: 0.6060 - val_accuracy: 0.7079 - val_loss: 0.6262
# Epoch 37/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.7587 - loss: 0.5978 - val_accuracy: 0.7778 - val_loss: 0.6090
# Epoch 38/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.7695 - loss: 0.5896 - val_accuracy: 0.7540 - val_loss: 0.6059
# Epoch 39/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.7745 - loss: 0.5872 - val_accuracy: 0.7286 - val_loss: 0.6074
# Epoch 40/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 197s 5s/step - accuracy: 0.7816 - loss: 0.5653 - val_accuracy: 0.8016 - val_loss: 0.5887
# Epoch 41/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 204s 5s/step - accuracy: 0.7803 - loss: 0.5695 - val_accuracy: 0.7635 - val_loss: 0.5827
# Epoch 42/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 200s 5s/step - accuracy: 0.7842 - loss: 0.5651 - val_accuracy: 0.8095 - val_loss: 0.5724
# Epoch 43/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.7848 - loss: 0.5565 - val_accuracy: 0.7270 - val_loss: 0.5923
# Epoch 44/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.7966 - loss: 0.5459 - val_accuracy: 0.7270 - val_loss: 0.5727
# Epoch 45/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.7963 - loss: 0.5436 - val_accuracy: 0.7238 - val_loss: 0.5886
# Epoch 46/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 197s 5s/step - accuracy: 0.7930 - loss: 0.5390 - val_accuracy: 0.7429 - val_loss: 0.5578
# Epoch 47/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 195s 5s/step - accuracy: 0.8048 - loss: 0.5279 - val_accuracy: 0.8016 - val_loss: 0.5548
# Epoch 48/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.8085 - loss: 0.5244 - val_accuracy: 0.8063 - val_loss: 0.5427
# Epoch 49/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.8033 - loss: 0.5256 - val_accuracy: 0.7460 - val_loss: 0.5635
# Epoch 50/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 191s 5s/step - accuracy: 0.8164 - loss: 0.5038 - val_accuracy: 0.8079 - val_loss: 0.5360
# Epoch 51/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.8181 - loss: 0.4972 - val_accuracy: 0.7746 - val_loss: 0.5296
# Epoch 52/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 191s 5s/step - accuracy: 0.8339 - loss: 0.4856 - val_accuracy: 0.7778 - val_loss: 0.5255
# Epoch 53/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 191s 5s/step - accuracy: 0.8265 - loss: 0.4908 - val_accuracy: 0.7857 - val_loss: 0.5257
# Epoch 54/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.8354 - loss: 0.4753 - val_accuracy: 0.8079 - val_loss: 0.5142
# Epoch 55/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.8268 - loss: 0.4776 - val_accuracy: 0.7667 - val_loss: 0.5363
# Epoch 56/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 191s 5s/step - accuracy: 0.8320 - loss: 0.4782 - val_accuracy: 0.8063 - val_loss: 0.5060
# Epoch 57/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.8472 - loss: 0.4482 - val_accuracy: 0.8063 - val_loss: 0.5056
# Epoch 58/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 191s 5s/step - accuracy: 0.8442 - loss: 0.4623 - val_accuracy: 0.8190 - val_loss: 0.4942
# Epoch 59/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.8462 - loss: 0.4493 - val_accuracy: 0.8000 - val_loss: 0.4906
# Epoch 60/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 189s 5s/step - accuracy: 0.8505 - loss: 0.4449 - val_accuracy: 0.8143 - val_loss: 0.4946
# Epoch 61/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.8405 - loss: 0.4503 - val_accuracy: 0.8222 - val_loss: 0.4835
# Epoch 62/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 200s 5s/step - accuracy: 0.8498 - loss: 0.4509 - val_accuracy: 0.8079 - val_loss: 0.4820
# Epoch 63/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 200s 5s/step - accuracy: 0.8653 - loss: 0.4265 - val_accuracy: 0.8159 - val_loss: 0.4794
# Epoch 64/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step - accuracy: 0.8593 - loss: 0.4222 - val_accuracy: 0.8206 - val_loss: 0.4773
# Epoch 65/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.8696 - loss: 0.4177 - val_accuracy: 0.8270 - val_loss: 0.4678
# Epoch 66/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 189s 5s/step - accuracy: 0.8687 - loss: 0.4150 - val_accuracy: 0.8238 - val_loss: 0.4647
# Epoch 67/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.8715 - loss: 0.4050 - val_accuracy: 0.8429 - val_loss: 0.4657
# Epoch 68/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 189s 5s/step - accuracy: 0.8732 - loss: 0.4026 - val_accuracy: 0.8238 - val_loss: 0.4687
# Epoch 69/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.8653 - loss: 0.4020 - val_accuracy: 0.8349 - val_loss: 0.4589
# Epoch 70/70
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 189s 5s/step - accuracy: 0.8844 - loss: 0.3921 - val_accuracy: 0.8444 - val_loss: 0.4476

# %%
figure = plt.figure(figsize=(5, 5))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='val_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(5, 5))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 332ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84       315
#            1       0.83      0.87      0.85       315
#
#     accuracy                           0.84       630
#    macro avg       0.85      0.84      0.84       630
# weighted avg       0.85      0.84      0.84       630

# %%
model.save('parkinson_disease_detectioncnn.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=['Healthy', 'Parkinson'], columns=['Healthy', 'Parkinson'])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.show()

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread("static/uploads/spiral_healthy.jpg")
image_parkinson = cv2.imread("parkinsons disease detection/spiral_parkinson.jpg")

image_healthy = np.array(image_healthy)
image_healthy = nimage_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = model.predict(image_healthy)
ypred_parkinson = model.predict(image_parkinson)
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()
