# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import tensorflow as tf

# %%
# **Loading Dataset**
data_train = np.load('/content/train.npz', allow_pickle=True)
x_train = data_train['images']
y_train = data_train['labels']

data_test = np.load('/content/test.npz', allow_pickle=True)
x_test = data_test['images']
y_test = data_test['labels']

# %%
train_data_generator = ImageDataGenerator(
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,  # Vertical flip might not make sense depending on your dataset

)


x = list(x_train)
y = list(y_train)

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(10):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)
print(len(x_aug_train))
print(len(y_aug_train))

x_train = x + x_aug_train
y_train = y + y_aug_train
print(len(x_train))
print(len(y_train))

test_data_generator = ImageDataGenerator(rotation_range=5,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True,
                                    vertical_flip=True)

x = list(x_test)
y = list(y_test)

x_aug_test = []
y_aug_test = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(5):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)
print(len(x_aug_test))
print(len(y_aug_test))

x_test = x + x_aug_test
y_test = y + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 720
# 720
# 792
# 792
# 150
# 150
# 180
# 180

# %%
# **Data Preprocessing**
x_train = np.array(x_train)
x_test = np.array(x_test)

# Initialize new arrays for resized images
x_train_resized = np.empty((x_train.shape[0], 224, 224, 3), dtype=np.float32)
x_test_resized = np.empty((x_test.shape[0], 224, 224, 3), dtype=np.float32)


for i in range(len(x_train)):
    img = x_train[i]
    img = cv2.resize(img, (224, 224))  # ResNet101 requires 224x224 input size
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    x_train_resized[i] = img

for i in range(len(x_test)):
    img = x_test[i]
    img = cv2.resize(img, (224, 224))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    x_test_resized[i] = img

# Normalize the images
x_train_resized /= 255.0
x_test_resized /= 255.0

# Use the resized images for training and testing
x_train = x_train_resized
x_test = x_test_resized

# Encoding labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.fit_transform(y_test)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# **Model Defining**
def create_resnet101_model(input_shape=(224, 224, 3)):
    base_model = ResNet101(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model

    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = Flatten()(x)
    x = Dropout(0.6)(x)
    x = Dense(64, activation='relu')(x)
    outputs = Dense(2, activation='softmax')(x)

    model = Model(inputs, outputs)
    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model = create_resnet101_model()
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_15 (InputLayer)          │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet101 (Functional)               │ (None, 7, 7, 2048)          │      42,658,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_7 (Flatten)                  │ (None, 100352)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 100352)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 64)                  │       6,422,592 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 49,080,898 (187.23 MB)
#  Trainable params: 6,422,722 (24.50 MB)
#  Non-trainable params: 42,658,176 (162.73 MB)

# %%
# **Model Training**
hist = model.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 789ms/step - accuracy: 0.5117 - loss: 0.9320 - val_accuracy: 0.5000 - val_loss: 0.8112
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 202ms/step - accuracy: 0.4930 - loss: 0.8458 - val_accuracy: 0.5000 - val_loss: 0.7249
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.5224 - loss: 0.7391 - val_accuracy: 0.5111 - val_loss: 0.6929
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.5481 - loss: 0.6998 - val_accuracy: 0.4944 - val_loss: 0.6954
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 0.5366 - loss: 0.6898 - val_accuracy: 0.5000 - val_loss: 0.7224
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.5574 - loss: 0.7050 - val_accuracy: 0.4889 - val_loss: 0.6974
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.6000 - loss: 0.6623 - val_accuracy: 0.5111 - val_loss: 0.6936
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.5578 - loss: 0.6877 - val_accuracy: 0.5722 - val_loss: 0.6939
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.5535 - loss: 0.6919 - val_accuracy: 0.5333 - val_loss: 0.6907
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.5218 - loss: 0.6826 - val_accuracy: 0.5167 - val_loss: 0.6934
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.5393 - loss: 0.6854 - val_accuracy: 0.5611 - val_loss: 0.6876
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 204ms/step - accuracy: 0.5810 - loss: 0.6708 - val_accuracy: 0.5389 - val_loss: 0.6955
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.5588 - loss: 0.6741 - val_accuracy: 0.5833 - val_loss: 0.6849
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.6063 - loss: 0.6667 - val_accuracy: 0.5278 - val_loss: 0.7032
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 205ms/step - accuracy: 0.5618 - loss: 0.6786 - val_accuracy: 0.6167 - val_loss: 0.6876
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.5629 - loss: 0.6639 - val_accuracy: 0.5722 - val_loss: 0.6821
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.5876 - loss: 0.6883 - val_accuracy: 0.5611 - val_loss: 0.6819
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.5931 - loss: 0.6592 - val_accuracy: 0.6056 - val_loss: 0.6933
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - accuracy: 0.5872 - loss: 0.6469 - val_accuracy: 0.5556 - val_loss: 0.7127
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.6031 - loss: 0.6462 - val_accuracy: 0.6111 - val_loss: 0.6805
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.5880 - loss: 0.6417 - val_accuracy: 0.6056 - val_loss: 0.6736
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.5580 - loss: 0.6656 - val_accuracy: 0.6000 - val_loss: 0.6655
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.6190 - loss: 0.6447 - val_accuracy: 0.5556 - val_loss: 0.6790
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.6492 - loss: 0.6192 - val_accuracy: 0.6222 - val_loss: 0.6599
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.5954 - loss: 0.6547 - val_accuracy: 0.6389 - val_loss: 0.6605
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.6509 - loss: 0.6172 - val_accuracy: 0.5722 - val_loss: 0.6647
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 206ms/step - accuracy: 0.6529 - loss: 0.6380 - val_accuracy: 0.6278 - val_loss: 0.6522
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.6758 - loss: 0.6126 - val_accuracy: 0.6444 - val_loss: 0.6603
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.5883 - loss: 0.6350 - val_accuracy: 0.6500 - val_loss: 0.6656
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.6056 - loss: 0.6283 - val_accuracy: 0.6667 - val_loss: 0.6517
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 206ms/step - accuracy: 0.5780 - loss: 0.6181 - val_accuracy: 0.6556 - val_loss: 0.6330
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.6639 - loss: 0.6133 - val_accuracy: 0.6111 - val_loss: 0.6641
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.6465 - loss: 0.6180 - val_accuracy: 0.6611 - val_loss: 0.6209
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.6723 - loss: 0.5922 - val_accuracy: 0.6667 - val_loss: 0.6185
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.6653 - loss: 0.6116 - val_accuracy: 0.6833 - val_loss: 0.6122
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.6799 - loss: 0.5921 - val_accuracy: 0.6778 - val_loss: 0.6024
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.6554 - loss: 0.6035 - val_accuracy: 0.6778 - val_loss: 0.6007
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.6718 - loss: 0.5944 - val_accuracy: 0.6889 - val_loss: 0.6052
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.6799 - loss: 0.6017 - val_accuracy: 0.6833 - val_loss: 0.5936
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.6697 - loss: 0.5904 - val_accuracy: 0.7000 - val_loss: 0.5992
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.7218 - loss: 0.5635 - val_accuracy: 0.7000 - val_loss: 0.6161
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.6589 - loss: 0.5974 - val_accuracy: 0.7167 - val_loss: 0.6002
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.6709 - loss: 0.5900 - val_accuracy: 0.6889 - val_loss: 0.6155
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.6528 - loss: 0.5977 - val_accuracy: 0.7167 - val_loss: 0.5987
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.6999 - loss: 0.5794 - val_accuracy: 0.5722 - val_loss: 0.6634
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.6699 - loss: 0.5984 - val_accuracy: 0.5500 - val_loss: 0.6890
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.6865 - loss: 0.5735 - val_accuracy: 0.7000 - val_loss: 0.5775
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.6994 - loss: 0.5571 - val_accuracy: 0.7056 - val_loss: 0.5738
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - accuracy: 0.6879 - loss: 0.5678 - val_accuracy: 0.6833 - val_loss: 0.6072
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.7206 - loss: 0.5636 - val_accuracy: 0.7000 - val_loss: 0.5710

# %%
# **Visualization of Training History**
plt.figure(figsize=(4,4))
plt.plot(hist.history['accuracy'], label='Train Accuracy')
plt.plot(hist.history['val_accuracy'], label='Test Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.plot(hist.history['loss'], label='Train Loss')
plt.plot(hist.history['val_loss'], label='Test Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
# **Save the Model**
model.save('resnet101.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# **Evaluation**
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.70        90
#            1       0.70      0.69      0.70        90
#
#     accuracy                           0.70       180
#    macro avg       0.70      0.70      0.70       180
# weighted avg       0.70      0.70      0.70       180

# %%
# **Confusion Matrix**
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=['Healthy', 'Parkinson'], columns=['Healthy', 'Parkinson'])
plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.show()

# %%
# **Testing with Sample Images**
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread('Parkinson_disease_detection/test_image_healthy.png')
image_parkinson = cv2.imread('Parkinson_disease_detection/test_image_parkinson.png')

def prepare_image(image):
    image = cv2.resize(image, (224, 224))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = np.array(image) / 255.0
    image = np.expand_dims(image, axis=0)
    return image

# %%
image_healthy_prepared = prepare_image(image_healthy)
image_parkinson_prepared = prepare_image(image_parkinson)

# %%
ypred_healthy = model.predict(image_healthy_prepared)
ypred_parkinson = model.predict(image_parkinson_prepared)
# Out:
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 137ms/step

# %%
plt.figure(figsize=(2, 2))
plt.imshow(image_healthy_prepared[0])
plt.axis('off')
plt.title(f'Prediction: {labels[np.argmax(ypred_healthy[0])]}')
plt.show()

# %%
plt.figure(figsize=(2, 2))
plt.imshow(image_parkinson_prepared[0])
plt.axis('off')
plt.title(f'Prediction: {labels[np.argmax(ypred_parkinson[0])]}')
plt.show()
